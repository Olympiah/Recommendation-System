# %% [markdown]
# ####**Extracting features of 2018 movies from Wikipedia**

# %%
import pandas as pd
import numpy as np

# %%
# Web scrpping from wikipedia

link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

df1 = pd.read_html(link, header=0)[2] # getting the 2nd table
df2 = pd.read_html(link, header=0)[3] # 3rd table
df3 = pd.read_html(link, header=0)[4] # 4th table
df4 = pd.read_html(link, header=0)[5] # 5th table

# %%
df1.head()
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y         12             The Commuter
# 3  J A N U A R Y         12               Proud Mary
# 4  J A N U A R Y         12         Acts of Violence
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2      Lionsgate / StudioCanal / The Picture Company
# 3                                        Screen Gems
# 4                                 Lionsgate Premiere
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Christopher Radcliff (director/screenplay); La...
# 2  Jaume Collet-Serra (director); Byron Willinger...
# 3  Babak Najafi (director); John S. Newman, Chris...
# ...

# %%
#concatenating all the data
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 237  D E C E M B E R         21               Second Act
# 238  D E C E M B E R         25          Holmes & Watson
# 239  D E C E M B E R         25                     Vice
# 240  D E C E M B E R         25      On the Basis of Sex
# 241  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# ...

# %%
df.shape
# Out:
# (242, 7)

# %% [markdown]
# As it is observed in the above table, we do not have the **genre** column so we will get the genre data from IMDb. You will need to create an API key in order to access the API key.

# %%
# !pip3 install tmdbv3api

# %%
#get your API Key here: https://www.themoviedb.org/settings/api
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'e275a3fe6d65fe2a7569c3540d72634c' #add your own API key here

# %%
from tmdbv3api import Movie

tmdb_movie = Movie()

def get_genre(x): #pass in the title of the movies
    genres = []
    #the title will be searched in the tmdb_movie
    result = tmdb_movie.search(x)
    #Matching the "id" with the "title"
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #gets the result from the IMDb data
    data_json = response.json() #converts it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.NaN # we will return the results but if we don't find anything we will consider it as a missing value

# %%
#Creating a new column 'genres' and populating the df
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 237  D E C E M B E R         21               Second Act
# 238  D E C E M B E R         25          Holmes & Watson
# 239  D E C E M B E R         25                     Vice
# 240  D E C E M B E R         25      On the Basis of Sex
# 241  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# ...

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 237               Second Act
# 238          Holmes & Watson
# 239                     Vice
# 240      On the Basis of Sex
# 241                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 237  Peter Segal (director); Justin Zackham, Elaine...
# 238  Etan Cohen (director/screenplay); Will Ferrell...
# 239  Adam McKay (director/screenplay); Christian Ba...
# ...

# %% [markdown]
# **Extract Directors**

# %%
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
#let's apply the above function on the "Cast and crew" column
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-14-e4fd6ee00db5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres                                      director_name
# 0  Horror Mystery Thriller                                       Adam Robitel
# 1            Drama Mystery  Christopher Radcliff (director/screenplay); La...
# 2  Action Thriller Mystery                                 Jaume Collet-Serra
# 3    Thriller Action Crime                                       Babak Najafi
# 4    Action Crime Thriller                                      Brett Donowho

# %% [markdown]
# **Actor 1**

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
# Creating an 'actor_1_name" column and populating df
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-18-01c3e9bf3e53>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %% [markdown]
# **Actor 2**

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-20-75f2be6b779a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %% [markdown]
# **Actor 3**

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-22-c6969dc4d5e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres                                      director_name  \
# 0  Horror Mystery Thriller                                       Adam Robitel
# 1            Drama Mystery  Christopher Radcliff (director/screenplay); La...
# 2  Action Thriller Mystery                                 Jaume Collet-Serra
# 3    Thriller Action Crime                                       Babak Najafi
# 4    Action Crime Thriller                                      Brett Donowho
#
# ...

# %%
# Renaming the column
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
#Slicing the df to select the columns listed
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18.head()
# Out:
#                                        director_name  \
# 0                                       Adam Robitel
# 1  Christopher Radcliff (director/screenplay); La...
# 2                                 Jaume Collet-Serra
# 3                                       Babak Najafi
# 4                                      Brett Donowho
#
#                                  actor_1_name            actor_2_name  \
# 0                                   Lin Shaye           Angus Sampson
# 1  Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                 Liam Neeson            Vera Farmiga
# 3                            Taraji P. Henson    Jahi Di'Allo Winston
# 4                                Bruce Willis             Cole Hauser
#
#      actor_3_name                   genres              movie_title
# 0  Leigh Whannell  Horror Mystery Thriller  Insidious: The Last Key
# 1   Emily Althaus            Drama Mystery         The Strange Ones
# ...

# %%
# Replace all the missing values with the work 'unknown'
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18.head()
# Out:
#                                        director_name  \
# 0                                       Adam Robitel
# 1  Christopher Radcliff (director/screenplay); La...
# 2                                 Jaume Collet-Serra
# 3                                       Babak Najafi
# 4                                      Brett Donowho
#
#                                  actor_1_name            actor_2_name  \
# 0                                   Lin Shaye           Angus Sampson
# 1  Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                 Liam Neeson            Vera Farmiga
# 3                            Taraji P. Henson    Jahi Di'Allo Winston
# 4                                Bruce Willis             Cole Hauser
#
#      actor_3_name                   genres              movie_title  \
# 0  Leigh Whannell  Horror Mystery Thriller  insidious: the last key
# 1   Emily Althaus            Drama Mystery         the strange ones
# ...

# %% [markdown]
# ###**Extracting features of 2019 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.head()
# Out:
#          Opening  Opening.1             Title  \
# 0  J A N U A R Y          4       Escape Room
# 1  J A N U A R Y          4        Rust Creek
# 2  J A N U A R Y          4  American Hangman
# 3  J A N U A R Y         11  A Dog's Way Home
# 4  J A N U A R Y         11        The Upside
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
# 3                  Columbia Pictures
# 4                  STX Entertainment
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                         genres
# 0      Horror Thriller Mystery
# 1  Thriller Drama Action Crime
# 2                     Thriller
# 3       Drama Adventure Family
# 4                 Comedy Drama

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-39-a433a4faa834>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-41-eee71c5586b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-43-48d0aadc78c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19.head()
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                       genres       movie_title  \
# 0  Deborah Ann Woll      Horror Thriller Mystery       escape room
# 1      Sean O'Bryan  Thriller Drama Action Crime        rust creek
# 2     Oliver Dennis                     Thriller  american hangman
# 3   Alexandra Shipp       Drama Adventure Family  a dog's way home
# 4     Nicole Kidman                 Comedy Drama        the upside
#
#                                                 comb
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# ...

# %%
# Joining the 2 dataframes

my_df = new_df18._append(new_df19,ignore_index=True)
my_df.head()
# Out:
#                                        director_name  \
# 0                                       Adam Robitel
# 1  Christopher Radcliff (director/screenplay); La...
# 2                                 Jaume Collet-Serra
# 3                                       Babak Najafi
# 4                                      Brett Donowho
#
#                                  actor_1_name            actor_2_name  \
# 0                                   Lin Shaye           Angus Sampson
# 1  Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                 Liam Neeson            Vera Farmiga
# 3                            Taraji P. Henson    Jahi Di'Allo Winston
# 4                                Bruce Willis             Cole Hauser
#
#      actor_3_name                   genres              movie_title  \
# 0  Leigh Whannell  Horror Mystery Thriller  insidious: the last key
# 1   Emily Althaus            Drama Mystery         the strange ones
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive'
# Out:
# /content/drive

# %%
data_dir = '/content/drive/MyDrive/movie_data'

old_df = pd.read_csv(data_dir +'/new_data.csv')
old_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
final_df = old_df._append(my_df,ignore_index=True)
final_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv(data_dir +'/final_data.csv',index=False)
